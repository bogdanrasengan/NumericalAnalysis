# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# $\text{Метод эйлера: }$  <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/e668e4e58dd7ff4206af64d6320f3f3d95f5aa92" class="mwe-math-fallback-image-inline" aria-hidden="true" style="vertical-align: -0.838ex; width:28.617ex; height:2.843ex;" alt=" y_i = y_{i-1} + h f(x_{i-1}, y_{i-1}). \quad">

# %%
h = 0.01
n = 100
xi = np.cumsum([h] * n)
function = lambda x, y: (3 * x**2) / (x**3 + y + 1)
exact_solution = lambda x: -x**3 - 2

# %%
def Euler(transfer_function, x0 = 0, y0 = -2):
    yi = []
    for i in range(n):
        y0 = y0 + h * function(x, y0)
        x = x + h
        yi.append(y0)
    return yi

# %%
Euler(function) - exact_solutionion(xi)
# Out:
# array([ 1.00000000e-03,  4.99699700e-03,  1.19367319e-02,  2.16105465e-02,
#         3.35503284e-02,  4.69467012e-02,  6.06267010e-02,  7.31393917e-02,
#         8.29885016e-02,  8.89972769e-02,  9.06898090e-02,  8.84861010e-02,
#         8.35492795e-02,  7.73280439e-02,  7.10484603e-02,  6.54228279e-02,
#         6.06608344e-02,  5.66715333e-02,  5.32775249e-02,  5.03308790e-02,
#         4.77328811e-02,  4.54168229e-02,  4.33340772e-02,  4.14477699e-02,
#         3.97291014e-02,  3.81550906e-02,  3.67070652e-02,  3.53696414e-02,
#         3.41299789e-02,  3.29772617e-02,  3.19022741e-02,  3.08971380e-02,
#         2.99549983e-02,  2.90700092e-02,  2.82367845e-02,  2.74513235e-02,
#         2.67079777e-02,  2.60083336e-02,  2.53316754e-02,  2.47390917e-02,
#         2.39792230e-02,  2.40810186e-02,  2.04997380e-02,  3.44078377e-02,
#        -3.95539926e-02,  3.27593698e-01, -2.62612687e+00,  2.31530332e+00,
#         1.46273649e+01,  2.25069337e+01,  3.05066585e+01,  3.87281073e+01,
#         4.72121194e+01,  5.59814742e+01,  6.50515823e+01,  7.44342650e+01,
#         8.41393796e+01,  9.41756164e+01,  1.04550928e+02,  1.15272777e+02,
#         1.26348288e+02,  1.37784344e+02,  1.49587651e+02,  1.61764786e+02,
#         1.74322221e+02,  1.87266350e+02,  2.00603508e+02,  2.14339977e+02,
#         2.28482000e+02,  2.43035787e+02,  2.58007522e+02,  2.73403364e+02,
#         2.89229456e+02,  3.05491922e+02,  3.22196875e+02,  3.39350412e+02,
#         3.56958626e+02,  3.75027595e+02,  3.93563394e+02,  4.12572088e+02,
#         4.32059738e+02,  4.52032400e+02,  4.72496124e+02,  4.93456957e+02,
#         5.14920941e+02,  5.36894117e+02,  5.59382521e+02,  5.82392186e+02,
#         6.05929146e+02,  6.29999428e+02,  6.54609061e+02,  6.79764070e+02,
#         7.05470479e+02,  7.31734311e+02,  7.58561587e+02,  7.85958326e+02,
#         8.13930549e+02,  8.42484271e+02,  8.71625511e+02,  9.01360283e+02])

# %%
plt.plot(xi, Euler(function))
plt.show()    
plt.plot(xi, exact_solution(xi))
plt.show()
plt.plot(xi, Euler(function)) 
plt.plot(xi, exact_solution(xi))

# %% [markdown]
# $\text{Модифицированный метод Эйлера второго порядка точности: }$ <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/e1ee988af6b29d4f7f08660b2ac06a7068753a10">

# %%
def Euler2(function, x = 0, y0 = -2):
    y = y0
    yi = []
    for i in range(n):
        y0 += h * function(x, y0)
        y += h * (function(x, y) + function(x + h, y0) ) / 2
        x += h
        yi.append(y)
    return yi

# %%
Euler2(function) - exact_solution(xi)
# Out:
# array([-5.00001500e-07, -1.00003075e-06, -1.50018675e-06, -2.00069450e-06,
#        -2.50195898e-06, -3.00461907e-06, -3.50960148e-06, -4.01817443e-06,
#        -4.53200129e-06, -5.05319391e-06, -5.58436569e-06, -6.12868421e-06,
#        -6.68992345e-06, -7.27251533e-06, -7.88160066e-06, -8.52307916e-06,
#        -9.20365862e-06, -9.93090289e-06, -1.07132787e-05, -1.15602010e-05,
#        -1.24820767e-05, -1.34903470e-05, -1.45975272e-05, -1.58172448e-05,
#        -1.71642756e-05, -1.86545764e-05, -2.03053157e-05, -2.21349016e-05,
#        -2.41630057e-05, -2.64105847e-05, -2.88998980e-05, -3.16545209e-05,
#        -3.46993553e-05, -3.80606347e-05, -4.17659255e-05, -4.58441239e-05,
#        -5.03254474e-05, -5.52414220e-05, -6.06248631e-05, -6.65098525e-05,
#        -7.29317088e-05, -7.99269524e-05, -8.75332649e-05, -9.57894420e-05,
#        -1.04735341e-04, -1.14411823e-04, -1.24860685e-04, -1.36124592e-04,
#        -1.48246996e-04, -1.61272056e-04, -1.75244543e-04, -1.90209748e-04,
#        -2.06213380e-04, -2.23301452e-04, -2.41520171e-04, -2.60915821e-04,
#        -2.81534629e-04, -3.03422642e-04, -3.26625589e-04, -3.51188738e-04,
#        -3.77156757e-04, -4.04573558e-04, -4.33482152e-04, -4.63924487e-04,
#        -4.95941295e-04, -5.29571929e-04, -5.64854204e-04, -6.01824227e-04,
#        -6.40516243e-04, -6.80962463e-04, -7.23192906e-04, -7.67235237e-04,
#        -8.13114604e-04, -8.60853487e-04, -9.10471539e-04, -9.61985439e-04,
#        -1.01540875e-03, -1.07075177e-03, -1.12802143e-03, -1.18722111e-03,
#        -1.24835057e-03, -1.31140585e-03, -1.37637912e-03, -1.44325861e-03,
#        -1.51202855e-03, -1.58266908e-03, -1.65515619e-03, -1.72946168e-03,
#        -1.80555314e-03, -1.88339388e-03, -1.96294300e-03, -2.04415531e-03,
#        -2.12698143e-03, -2.21136776e-03, -2.29725657e-03, -2.38458605e-03,
#        -2.47329037e-03, -2.56329980e-03, -2.65454082e-03, -2.74693619e-03])

# %%
plt.plot(xi, Euler2(function))
plt.show()
plt.plot(xi, exact_solution(xi))
plt.show()
plt.plot(xi, Euler2(function))
plt.plot(xi, exact_solution(xi))

# %% [markdown]
# $ \text{ Метод Рунге-Кутты:  } $ <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/69154de8cfe616c86675c6eb01f90d67f577252d" >

# %% [markdown]
# $\text{Где, }$ <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/120b207ca055bd888933127f5d9e906133580f50">$$\$$ <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/9c91ca156e16bc16fbcc6caf07b7e450e417539b">

# %% [markdown]
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9a0abc4b82c32f99b14f1003c5adbb27934bdad"> $$\$$ <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/b2afedb0fa23665b955213f7ff81f680ad97b091">

# %%
k1 = lambda x, y: function(x,y)     
k2 = lambda k1, x, y, h: function(x + h/2 , y + (h*k1) / 2) 
k3 = lambda k2, x, y, h: function(x + h/2 , y + (h*k2) / 2)    
k4 = lambda k3, x, y, h: function(x + h, y + h * k3)           

def Euler4(function, x = 0, y0 = -2):
    y = y0
    yi = []
    for i in range(n):
        k_1 = k1(x, y)
        k_2 = k2(k_1, x, y, h)
        k_3 = k3(k_2, x, y, h)
        k_4 = k4(k_3, x, y, h)
        y = y + h * (k_1 + 2*k_2 + 2*k_3 + k_4) / 6
        x = x + h
        yi.append(y)
    return yi

# %%
Euler4(function) - exact_solution(xi)
# Out:
# array([-9.37028233e-14, -3.12638804e-13, -6.55919763e-13, -1.12532206e-12,
#        -1.71995751e-12, -2.44071430e-12, -3.28848060e-12, -4.26414459e-12,
#        -5.36948264e-12, -6.60671517e-12, -7.97717448e-12, -9.48485734e-12,
#        -1.11328724e-11, -1.29252165e-11, -1.48672186e-11, -1.69646519e-11,
#        -1.92237337e-11, -2.16520135e-11, -2.42574849e-11, -2.70494738e-11,
#        -3.00381942e-11, -3.32347483e-11, -3.66529029e-11, -4.03050926e-11,
#        -4.42068604e-11, -4.83746376e-11, -5.28257438e-11, -5.75797188e-11,
#        -6.26569907e-11, -6.80802081e-11, -7.38729078e-11, -8.00604028e-11,
#        -8.66697825e-11, -9.37312450e-11, -1.01274988e-10, -1.09333875e-10,
#        -1.17943433e-10, -1.27140520e-10, -1.36964218e-10, -1.47455825e-10,
#        -1.58659308e-10, -1.70620407e-10, -1.83387971e-10, -1.97013073e-10,
#        -2.11548556e-10, -2.27051711e-10, -2.43581155e-10, -2.61198618e-10,
#        -2.79968937e-10, -2.99960057e-10, -3.21242144e-10, -3.43889806e-10,
#        -3.67980313e-10, -3.93593602e-10, -4.20813606e-10, -4.49728699e-10,
#        -4.80429030e-10, -5.13009635e-10, -5.47569101e-10, -5.84209570e-10,
#        -6.23037621e-10, -6.64163391e-10, -7.07702341e-10, -7.53772156e-10,
#        -8.02497180e-10, -8.54004423e-10, -9.08426667e-10, -9.65900249e-10,
#        -1.02656772e-09, -1.09057519e-09, -1.15807453e-09, -1.22922250e-09,
#        -1.30418121e-09, -1.38311851e-09, -1.46620538e-09, -1.55362168e-09,
#        -1.64555036e-09, -1.74218151e-09, -1.84371052e-09, -1.95033900e-09,
#        -2.06227391e-09, -2.17972929e-09, -2.30292541e-09, -2.43208786e-09,
#        -2.56745025e-09, -2.70925193e-09, -2.85773849e-09, -3.01316350e-09,
#        -3.17578586e-09, -3.34587380e-09, -3.52370044e-09, -3.70954689e-09,
#        -3.90370225e-09, -4.10646139e-09, -4.31812897e-09, -4.53901494e-09,
#        -4.76943907e-09, -5.00972686e-09, -5.26021271e-09, -5.52123991e-09])

# %%
plt.plot(xi, Euler4(function = function))
plt.show()
plt.plot(xi, exact_solution(xi))
plt.show()
plt.plot(xi, Euler4(function = function))
plt.plot(xi, exact_solution(xi))
